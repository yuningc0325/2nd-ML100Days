# %% [markdown]
# ## HW1 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
# #### Trending YouTube Video Statistics 資料來源: https://www.kaggle.com/datasnaek/youtube-new#CA_category_id.json
# ### 1. 你選的這組資料為何重要
# #### 可以觀察現今各個國家現今熱門影片為何，包含許多細項資料如分類 tag 按讚數 留言數等等
# ### 2. 資料從何而來
# #### 資料來源為 Mitchell J 由他撰寫的Trending-YouTube-Scraper爬蟲指令去向youtube api請求資料
# ### 3. 蒐集而來的資料型態為何
# #### CSV for vedio data, JSON for category
# ### 4. 這組資料想解決的問題如何評估
# #### 資料包含熱門影片ranking及許多細項，透過這些細項分析，譬如comment的內容,like dislike比率和熱門影片的關係
# #### 達到預測下一隻熱門影片有可能的類型，但其中作者inspiration想探究情緒分析，就可需要更多額外資訊了

# %% [markdown]
# ## HW2 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績
# ## ，請你思考並描述你如何規劃整
# ### 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# #### 首先定義提升業績，應為增加客人的搭車次數。假設一日分為白天下午晚上三個時段，透過長期的資料來顯示哪個時段為熱門時段
# #### 並於熱門時段派遣較多車，非熱門時段則透過location data，將車隊分佈於較多乘客的地方
# ### 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# #### 公部門資料庫或是搭車時透過預約系統(有的話) 紀錄搭車次數,搭車時間與乘客叫車地點
# ### 3. 蒐集而來的資料型態為何
# #### 若是系統的話可存於DB 要用時call其api取得JSON格式資料便可分析
# ### 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# #### 統計搭車時間區段之次數與上車地點次數統計，便可獲得rough data

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# MSE
def mean_squared_error(a,b):
    count = 0
    length = len(a)
    for i in range(len(a)):
        count = count+(a[i]-b[i])**2
    return count/length
# MAE
def mean_absolute_error(a,b):
    count = 0
    length = len(a)
    for i in range(len(a)):
        count = count+abs(a[i]-b[i])
    return count/length

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 178.524
# The Mean absolute error is 10.613
